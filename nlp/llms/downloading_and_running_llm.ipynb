# %% [markdown]
# The below implementation is taken from `Hands on Large Language Models` by Jay Alammar
#
# **Note:** although the book was released in 2024 some code is outdated and depricated, so installing the desired package versions for the code to work correctly.
#
# For More info See : [Phi-3 on HuggingFace](https://huggingface.co/microsoft/Phi-3-mini-4k-instruct)

# %%
# !pip install  torch==2.3.1 accelerate==0.31.0 transformers==4.41.2 # flash_attn==2.5.8

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# # Generate with `Phi-3-mini-4k-instruct`

# %%
# Load model and tokenizer
model = AutoModelForCausalLM.from_pretrained(
 "microsoft/Phi-3-mini-4k-instruct",
 device_map=device,
 torch_dtype="auto",
 trust_remote_code=True,
)
tokenizer = AutoTokenizer.from_pretrained("microsoft/Phi-3-mini-4k-instruct")

# %%
prompt = "Write an email apologizing to Sarah for the tragic \
    gardening mishap. Explain how it happened.<|assistant|"

tokenizer.pad_token = tokenizer.eos_token

inputs = tokenizer(prompt, return_tensors="pt", padding=True)

generation_output = model.generate(
    input_ids=inputs["input_ids"],
    attention_mask=inputs["attention_mask"],
    max_new_tokens=100
)

# %%
print(tokenizer.decode(generation_output[0], skip_special_tokens=True))
# Out:
# Write an email apologizing to Sarah for the tragic     gardening mishap. Explain how it happened.<|assistant|introduction|>
#
# Subject: Sincere Apologies for the Gardening Mishap
#
# Dear Sarah,
#
# I hope this email finds you well. I am writing to express my deepest apologies for the unfortunate incident that occurred in your garden recently. I understand that it was a tragic event and I am truly sorry for any distress it may have caused you.
#
# The incident happened on the 15th of April, when I was

# %%
color_list = [
    '102;194;165', '252;141;98', '141;160;203',
    '231;138;195', '166;216;84', '255;217;47'
]

def show_tokens(sentence, tokenizer_name):
 tokenizer = AutoTokenizer.from_pretrained(tokenizer_name)
 token_ids = tokenizer(sentence).input_ids
 for idx, t in enumerate(token_ids):
  print(f'\x1b[0;30;48;2;{colors_list[idx % len(colors_list)]}m'
        +  tokenizer.decode(t)
        +'\x1b[0m',end=' '
        )
